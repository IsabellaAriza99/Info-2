# %% [markdown]
# ### Transformada de Fourier

# %%
# importing the fft and inverse fft functions from fftpackage  
from scipy.fftpack import fft  
#Importing numpy  
import numpy as np  
#create an array with random n numbers  
x = np.random.rand(20)  
#Applying the fft function  
y = fft(x)  
print(x)
print(y)
# Out:
# [0.07525954 0.88589137 0.75930597 0.25839132 0.22749605 0.35316555
#  0.22903532 0.14572174 0.483122   0.98730277 0.57033889 0.09050506
#  0.46144221 0.379562   0.63518391 0.22377066 0.3280644  0.35426115
#  0.08093311 0.14895316]
# [ 7.67770618-0.j         -0.66436744-0.29707016j  0.82910091-0.8414224j
#  -0.32147672-2.05406959j -0.05042975+0.13776199j -0.69941299-2.09284092j
#  -0.66877369+0.3285028j  -0.10478511-0.12680884j -0.73208674+0.76691316j
#  -0.68535448-0.43794182j  0.02265661-0.j         -0.68535448+0.43794182j
#  -0.73208674-0.76691316j -0.10478511+0.12680884j -0.66877369-0.3285028j
#  -0.69941299+2.09284092j -0.05042975-0.13776199j -0.32147672+2.05406959j
#   0.82910091+0.8414224j  -0.66436744+0.29707016j]

# %% [markdown]
# ### Constantes físicas

# %%
from scipy import constants as C
C.c  # Velocidad de la luz en m/s
C.e  #Euler
C.Avogadro #Número de avogradro
C.Planck #Constante de plank
C.m_e #Masa del electrón
# Out:
# 9.1093837015e-31

# %% [markdown]
# ### Interpolación

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

datos_x = np.arange(0, 0.1, 0.005)
A, k, theta = 10.0, 33.3, np.pi/5.0
y_real = A*np.sin(2*np.pi*k*datos_x + theta)
datos_y = y_real + 2*np.random.randn(len(datos_x))

interpolador_lineal = interp1d(datos_x, datos_y)


x_inter = np.linspace(0.012, 0.09, 500)
y_inter_l = interpolador_lineal(x_inter)


plt.plot(datos_x, datos_y, 'ok', label="Datos")
plt.plot(x_inter, y_inter_l, 'r', label="Interpolación lineal")
plt.title("Interpolación")
plt.xlim(-0.003, 0.102)
plt.ylim(-14, 15)
plt.legend()

# %% [markdown]
# ### Inputs y outputs en scipy

# %%
import scipy.io as sio   
#Guardar un archivo .mat  
sio.savemat('python.mat', {'A1': [0, 1, 2], 'A2': 0})

#Cargar un archivo .mat    
mat_file_content = sio.loadmat('python.mat')  
print(sio.whosmat('python.mat'))
print(mat_file_content.keys())
mat_file_content['A1'].mean()
# Out:
# [('A1', (1, 3), 'int32'), ('A2', (1, 1), 'int32')]
# dict_keys(['__header__', '__version__', '__globals__', 'A1', 'A2'])
# 1.0
